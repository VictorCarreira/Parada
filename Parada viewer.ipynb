# %% [markdown]
#  <img src='Image/logon.jpg' width="500px" align="center">

# %% [markdown]
# <center size=4> Programa que gera as imagens do ajuste linear de mínimos quadrados <center size=4>

# %%
################PACOTES################
% matplotlib inline
import numpy as np
import pylab as py
import pandas as pd
from pandas import Series, DataFrame
import matplotlib
import matplotlib.pyplot as plt
import scipy as sp
from IPython.display import Latex
#####################################

# %%
#data = pd.read_csv('Dado.csv')
#data = np.array(data)
data=np.loadtxt('conv.txt')
print(data)
# Out:
# [[    1.    56.]
#  [    2.    46.]
#  [    3.    42.]
#  ...,
#  [  998.     1.]
#  [  999.     1.]
#  [ 1000.     1.]]

# %%
#Gerando o Gráfico de convergência:

x=data[:,0]
y=data[:,1]

py.rcParams['figure.figsize'] = (20.0, 10.0)#Redimensiona a figura

plt.plot( x, y, 'go') # green bolinha
plt.plot( x, y, 'k:', color='orange') # linha pontilha orange

plt.title("$Dado$ $Direto$", fontweight='bold', fontsize=25)
plt.tick_params(axis='both', labelsize=15)#aumenta o tamanho dos valores nos eixos

plt.grid(True)
plt.xlabel("$x$", fontsize=15)
plt.ylabel("$y$", fontsize=15)
plt.savefig('Image/Y.png')  
plt.show()  
plt.close()

# %%
ajuste=np.loadtxt('saida.txt')
print(ajuste)
# Out:
# [[  1.          56.          52.08113343]
#  [  2.          46.          45.92390338]
#  [  3.          42.          40.4081673 ]
#  [  4.          28.          35.46709084]
#  [  5.          31.          31.0408028 ]
#  [  6.          24.          27.07566971]
#  [  7.          23.          23.52364592]
#  [  8.          19.          20.34169143]
#  [  9.          26.          17.4912504 ]
#  [ 10.          19.          14.93778394]
#  [  1.          56.                  nan]
#  [  2.          46.                  nan]
#  [  3.          42.                  nan]
#  [  4.          28.                  nan]
#  [  5.          31.                  nan]
#  [  6.          24.                  nan]
#  [  7.          23.                  nan]
#  [  8.          19.                  nan]
#  [  9.          26.                  nan]
#  [ 10.          19.                  nan]
#  [ 11.          21.                  nan]
#  [ 12.          16.                  nan]
#  [ 13.          24.                  nan]
#  [ 14.          24.                  nan]
#  [ 15.          16.                  nan]
#  [ 16.          23.                  nan]
#  [ 17.          18.                  nan]
#  [ 18.          19.                  nan]
#  [ 19.          15.                  nan]
#  [ 20.          18.                  nan]
#  [ 21.          10.                  nan]
#  [ 22.          13.                  nan]
#  [ 23.          18.                  nan]
#  [ 24.          17.                  nan]
#  [ 25.          18.                  nan]
#  [ 26.          17.                  nan]
#  [ 27.          12.                  nan]
#  [ 28.          10.                  nan]
#  [ 29.          10.                  nan]
#  [ 30.          10.                  nan]
#  [ 31.          12.                  nan]
#  [ 32.          11.                  nan]
#  [ 33.          10.                  nan]
#  [ 34.          19.                  nan]
#  [ 35.          11.                  nan]
#  [ 36.          13.                  nan]
#  [ 37.          13.                  nan]
#  [ 38.           9.                  nan]
#  [ 39.          10.                  nan]
#  [ 40.          10.                  nan]
#  [ 41.          10.                  nan]
#  [ 42.          13.                  nan]
#  [ 43.          11.                  nan]
#  [ 44.          12.                  nan]
#  [ 45.          11.                  nan]
#  [ 46.          15.                  nan]
#  [ 47.          10.                  nan]
#  [ 48.          11.                  nan]
#  [ 49.          12.                  nan]
#  [ 50.           7.                  nan]
#  [ 51.           8.                  nan]
#  [ 52.          11.                  nan]
#  [ 53.          11.                  nan]
#  [ 54.          10.                  nan]
#  [ 55.           8.                  nan]
#  [ 56.           6.                  nan]
#  [ 57.           9.                  nan]
#  [ 58.           7.                  nan]
#  [ 59.           8.                  nan]
#  [ 60.          10.                  nan]]

# %%
#Gerando o Gráfico de convergência:

xx=ajuste[:,0]
yy=ajuste[:,1]

py.rcParams['figure.figsize'] = (20.0, 10.0)#Redimensiona a figura

plt.plot( xx, yy, 'bo') # green bolinha
plt.plot( xx, yy, 'k:', color='red') # linha pontilha orange

plt.title("$Dado$ $Inverso$", fontweight='bold', fontsize=25)
plt.tick_params(axis='both', labelsize=15)#aumenta o tamanho dos valores nos eixos

plt.grid(True)
plt.xlabel("$x$", fontsize=15)
plt.ylabel("$y$", fontsize=15)
plt.savefig('Image/Y.png')  
plt.show()  
plt.close()

# %%
py.rcParams['figure.figsize'] = (20.0, 10.0)#Redimensiona a figura

plt.plot( x, y, 'go') # green bolinha
plt.plot( x, y, 'k:', color='orange') # linha pontilha orange
plt.plot( xx, yy, 'bo') # green bolinha
plt.plot( xx, yy, 'k:', color='red') # linha pontilha orange

plt.title("$Dado$ $Inverso$", fontweight='bold', fontsize=25)
plt.tick_params(axis='both', labelsize=15)#aumenta o tamanho dos valores nos eixos

plt.grid(True)
plt.xlabel("$x$", fontsize=15)
plt.ylabel("$y$", fontsize=15)
plt.savefig('Image/comparacao.png')  
plt.show()  
plt.close()
